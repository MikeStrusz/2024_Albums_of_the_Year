# %% [markdown]
# # 2024 Albums of the Year

# %% [markdown]
# Welcome, casually observer, welcome to my year long journey to rank the 100 best albums of the year. Over the past 10.5 months, I have been listening to about a dozen albums a week, and putting the best albums in a spotify album called 2024.
#
# I've also been scrobbling every song I listen to on spotify to my account on last.fm.
#
# My intention is to pull the data from my 2024 playlist, my Liked Songs playlist, and my last.fm scrobbles, to pull data about each album, rank by scrobbles, likes, and a few feature engineering to spice things up.

# %%
import requests
import pandas as pd
import spotipy
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
from datetime import datetime
import os
import sqlite3

# %%
# Define the path to the Data folder
data_folder = os.path.join(os.getcwd(), 'Data')

# Create Data folder if it doesn't exist
if not os.path.exists(data_folder):
    os.makedirs(data_folder)

API_KEY = '74a510ecc9fc62bf3e0edc6adc2e99f9'
USERNAME = 'Strusz_Music'
BASE_URL = 'http://ws.audioscrobbler.com/2.0/'

# Get today's date in YYYY-MM-DD format
today = datetime.today().strftime('%Y-%m-%d')

# Set up SQLite database with today's date in the filename, saved inside the Data folder
db_filename = os.path.join(data_folder, f'lastfm_scrobbles_{today}.db')
conn = sqlite3.connect(db_filename)
cursor = conn.cursor()

# Create table if it doesn't exist (removed play_count, duration, and favorite)
cursor.execute('''
CREATE TABLE IF NOT EXISTS scrobbles (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    artist TEXT,
    title TEXT,
    album TEXT,
    release_date TEXT,
    album_art TEXT,
    timestamp INTEGER
)
''')

# Define the Unix timestamp for January 1, 2024 (00:00:00)
start_of_2024 = int(datetime(2024, 1, 1).timestamp())

# Function to get scrobbles
def get_scrobbles(page=1):
    params = {
        'method': 'user.getrecenttracks',
        'user': USERNAME,
        'api_key': API_KEY,
        'format': 'json',
        'limit': 200,
        'page': page
    }
    response = requests.get(BASE_URL, params=params)
    return response.json()

# Function to insert scrobbles into the database (removed play_count, duration, and favorite)
def insert_scrobbles(scrobbles):
    for track in scrobbles:
        artist = track.get('artist', {}).get('#text', 'Unknown')
        title = track.get('name', 'Unknown')
        album = track.get('album', {}).get('#text', 'Unknown')
        release_date = track.get('album', {}).get('releasedate', 'Unknown')
        album_art = track.get('image', [{}])[3].get('#text', '')  # Get the medium-sized image URL
        timestamp_str = track.get('date', {}).get('uts', '0')
        
        # Convert the timestamp from string to integer
        timestamp = int(timestamp_str)

        # Only insert scrobbles from 2024 onwards
        if timestamp >= start_of_2024:
            cursor.execute('''
            INSERT INTO scrobbles (artist, title, album, release_date, album_art, timestamp) 
            VALUES (?, ?, ?, ?, ?, ?)
            ''', (artist, title, album, release_date, album_art, timestamp))
    
    conn.commit()

# Fetch and store scrobbles
def fetch_and_store_scrobbles():
    page = 1
    while True:
        data = get_scrobbles(page)
        tracks = data.get('recenttracks', {}).get('track', [])
        if not tracks:
            break
        insert_scrobbles(tracks)
        page += 1

# Run the process
fetch_and_store_scrobbles()

# Close the database connection
conn.close()

# %% [markdown]
# I used DBbrowser to convert the db file.

# %% [markdown]
# ## IMPORT THE LAST.FM SCROBBLES.CSV

# %%
scrobbles = pd.read_csv('Data/scrobbles2.csv')

# %%
scrobbles.head()
# Out:
#    id          artist                                              title  \
# 0   1  Kendrick Lamar          gnx (feat. hitta j3, youngthreat, peysoh)
# 1   2  Kendrick Lamar                                        heart pt. 6
# 2   3  Kendrick Lamar                                        heart pt. 6
# 3   4  Kendrick Lamar                           peekaboo (feat. AzChike)
# 4   5  Kendrick Lamar  dodger blue (feat. wallie the sensei, siete7x,...
#
#   album release_date                                          album_art  \
# 0   GNX      Unknown  https://lastfm.freetls.fastly.net/i/u/300x300/...
# 1   GNX      Unknown  https://lastfm.freetls.fastly.net/i/u/300x300/...
# 2   GNX      Unknown  https://lastfm.freetls.fastly.net/i/u/300x300/...
# 3   GNX      Unknown  https://lastfm.freetls.fastly.net/i/u/300x300/...
# 4   GNX      Unknown  https://lastfm.freetls.fastly.net/i/u/300x300/...
#
#     timestamp
# 0  1732664212
# 1  1732663923
# 2  1732660866
# 3  1732660710
# 4  1732660579

# %%
scrobbles.columns
# Out:
# Index(['id', 'artist', 'title', 'album', 'release_date', 'album_art',
#        'timestamp'],
#       dtype='object')

# %%
# Drop the columns and update the DataFrame
scrobbles.drop(['id', 'release_date'], axis=1, inplace=True)

# Confirm the columns have been dropped
scrobbles.columns
# Out:
# Index(['artist', 'title', 'album', 'album_art', 'timestamp'], dtype='object')

# %% [markdown]
# Checking for double scrobbles, last.fm once and a while will count a song twice that you only listened to once.

# %%
scrobbles[scrobbles.duplicated(subset=['artist', 'title', 'album', 'timestamp'], keep=False)]
# Out:
#                  artist             title album  \
# 14915  Ivor Cutler Trio  Cockadoodledon't  Ludo
# 14916  Ivor Cutler Trio  Cockadoodledon't  Ludo
#
#                                                album_art   timestamp
# 14915  https://lastfm.freetls.fastly.net/i/u/300x300/...  1708646297
# 14916  https://lastfm.freetls.fastly.net/i/u/300x300/...  1708646297

# %% [markdown]
# Dropping one copy of each of these double scrobbles.

# %%
scrobbles.drop_duplicates(subset=['artist', 'title', 'album', 'timestamp'], inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Checking for Null Values:

# %%
scrobbles.isnull().sum()
# Out:
# artist        0
# title         0
# album        80
# album_art    80
# timestamp     0
# dtype: int64

# %%
# Set display options to show all rows and columns
pd.set_option('display.max_rows', 80)  # Show up to 80 rows
pd.set_option('display.max_columns', None)  # Show all columns

scrobbles[scrobbles['album'].isnull() | scrobbles['album_art'].isnull()]
# Out:
#                               artist  \
# 9285             889 Radio Milwaukee
# 9288             889 Radio Milwaukee
# 9289                     Jon Batiste
# 11852            889 Radio Milwaukee
# 11853            889 Radio Milwaukee
# 11854                          Tiawa
# 12123            889 Radio Milwaukee
# 12124                    Norah Jones
# 12592             Nation of Language
# 12593                        Justice
# 12596    Audrey Nuna/Teezo Touchdown
# 12599                    Andrew Bird
# 12600            889 Radio Milwaukee
# 12603                  Maggie Rogers
# 12604                    Jon Batiste
# 12606            889 Radio Milwaukee
# 12608            889 Radio Milwaukee
# 12609              Car Seat Headrest
# 12611            889 Radio Milwaukee
# 12613            889 Radio Milwaukee
# 12614            889 Radio Milwaukee
# 12617            889 Radio Milwaukee
# 12620                     Royel Otis
# 12621            889 Radio Milwaukee
# 12627            889 Radio Milwaukee
# 12639                    Kevin Morby
# 14079                 PinkPantheress
# 14080                          J Hus
# 14496            889 Radio Milwaukee
# 14498                 DJ DangerMouse
# 14499                   Juana Molina
# 14500            889 Radio Milwaukee
# 14501                       Yard Act
# 14504                   Rubblebucket
# 14505            889 Radio Milwaukee
# 14507            889 Radio Milwaukee
# 14509                   Faye Webster
# 14510            889 Radio Milwaukee
# 14531                      Baby Rose
# 14532                            SiR
# 14584                   Summer Pearl
# 14585               DJ Green Lantern
# 14591                         Huey V
# 15520                   Summer Pearl
# 15767                    Tkay Maidza
# 15774                         Noname
# 15777                Brittany Howard
# 15783                           Jayo
# 15784                           Tems
# 15829                   Debby Friday
# 15831                Brittany Howard
# 15836                     Black Milk
# 16816                 PinkPantheress
# 16819            Tank and the Bangas
# 16822    Uncle Waffles & Tony Duardo
# 16824                         Common
# 17278                    Tae the Don
# 17279                          Sipho
# 17283                    Killer Mike
# 17284            Cookiee Kawaii/Tyga
# 17290                           H31R
# 17291                     Black Milk
# 17301                   George Riley
# 17396  BJ The Chicago Kid/CoCo Jones
# 17399                  RichBwoy YoGa
# 17673                          Sahxl
# 17854                Beyond King Tut
# 17855                Beyond King Tut
# 17856                Beyond King Tut
# 17857                Beyond King Tut
# 17858                Beyond King Tut
# 17859                Beyond King Tut
# 17860                Beyond King Tut
# 17861                Beyond King Tut
# 17862                Beyond King Tut
# 17864                Beyond King Tut
# 17865                Beyond King Tut
# 17866                Beyond King Tut
# 17867                Beyond King Tut
# 17868                Beyond King Tut
#
#                                                title album album_art  \
# 9285                              Discover New Music   NaN       NaN
# 9288                              Discover New Music   NaN       NaN
# 9289                                          Uneasy   NaN       NaN
# 11852                             Discover New Music   NaN       NaN
# 11853                             Discover New Music   NaN       NaN
# 11854                             Sonhos Cor de Rosa   NaN       NaN
# 12123                             Discover New Music   NaN       NaN
# 12124                                        Running   NaN       NaN
# 12592                               Too Much, Enough   NaN       NaN
# 12593          One Night/All Night (Ft. Tame Impala)   NaN       NaN
# 12596                                       Starving   NaN       NaN
# 12599                                      Roma Fade   NaN       NaN
# 12600                             Discover New Music   NaN       NaN
# 12603                                DON’T forget me   NaN       NaN
# 12604                                         Uneasy   NaN       NaN
# 12606                             Discover New Music   NaN       NaN
# 12608                             Discover New Music   NaN       NaN
# 12609                             Can't Cool Me Down   NaN       NaN
# 12611                             Discover New Music   NaN       NaN
# 12613                             Discover New Music   NaN       NaN
# 12614                             Discover New Music   NaN       NaN
# 12617                             Discover New Music   NaN       NaN
# 12620                                           Foam   NaN       NaN
# 12621                             Discover New Music   NaN       NaN
# 12627                             Discover New Music   NaN       NaN
# 12639                                        No Halo   NaN       NaN
# 14079                      Another life (feat. Rema)   NaN       NaN
# 14080                                   Who Told You   NaN       NaN
# 14496                             Discover New Music   NaN       NaN
# 14498                            What More Can I Say   NaN       NaN
# 14499                                         Cosoco   NaN       NaN
# 14500                             Discover New Music   NaN       NaN
# 14501                        When The Laughter Stops   NaN       NaN
# 14504                                      Teardrops   NaN       NaN
# 14505                             Discover New Music   NaN       NaN
# 14507                             Discover New Music   NaN       NaN
# 14509                     Lego Ring (ft. Lil Yachty)   NaN       NaN
# 14510                             Discover New Music   NaN       NaN
# 14531                              Stop The Bleeding   NaN       NaN
# 14532                                        No Evil   NaN       NaN
# 14584                   feel right remix feat Visaka   NaN       NaN
# 14585  Step Into a World, Pt. 2 (feat. Amber Navran)   NaN       NaN
# 14591       MO MONEY MO PROBLEMS feat. Memphis Bleek   NaN       NaN
# 15520                   feel right remix feat Visaka   NaN       NaN
# 15767                               Don't Call Again   NaN       NaN
# 15774                                       oblivion   NaN       NaN
# 15777                                Prove It To You   NaN       NaN
# 15783                                             22   NaN       NaN
# 15784                                         Me & U   NaN       NaN
# 15829                                       let u in   NaN       NaN
# 15831                                Prove It To You   NaN       NaN
# 15836          No Wish (ft. Phonte & Raphael Saadiq)   NaN       NaN
# 16816                      Another life (feat. Rema)   NaN       NaN
# 16819                                     Spaceships   NaN       NaN
# 16822             Babiee (feat. Jelly Babie & Chley)   NaN       NaN
# 16824                        Black Maybe (Ft. Bilal)   NaN       NaN
# 17278                                       Oblivion   NaN       NaN
# 17279                                          Sober   NaN       NaN
# 17283                         Scientists & Engineers   NaN       NaN
# 17284                         Vibe (If I Back It Up)   NaN       NaN
# 17290                                   Down Down Bb   NaN       NaN
# 17291          No Wish (ft. Phonte & Raphael Saadiq)   NaN       NaN
# 17301                   S e x (feat. Hudson Mohawke)   NaN       NaN
# 17396                                Spend The Night   NaN       NaN
# 17399                                        Popular   NaN       NaN
# 17673                                           DSYL   NaN       NaN
# 17854                                Into the Future   NaN       NaN
# 17855                                  Egyptian Gods   NaN       NaN
# 17856                               Book of the Dead   NaN       NaN
# 17857                             Preparing the Body   NaN       NaN
# 17858                            Valley of the Kings   NaN       NaN
# 17859                               Book of the Dead   NaN       NaN
# 17860                                  Egyptian Gods   NaN       NaN
# 17861                                       The Nile   NaN       NaN
# 17862                                         Diadem   NaN       NaN
# 17864                                     Family DNA   NaN       NaN
# 17865                              Tut's Family Tree   NaN       NaN
# 17866                                  Egyptian Gods   NaN       NaN
# 17867                            Valley of the Kings   NaN       NaN
# 17868                                   Introduction   NaN       NaN
#
#         timestamp
# 9285   1718628917
# 9288   1718628469
# 9289   1718628157
# 11852  1713143094
# 11853  1713142876
# 11854  1713142722
# 12123  1712669006
# 12124  1712668878
# 12592  1711653831
# 12593  1711653406
# 12596  1711652758
# 12599  1711652082
# 12600  1711651963
# 12603  1711645570
# 12604  1711645247
# 12606  1711644977
# 12608  1711644699
# 12609  1711644394
# 12611  1711644095
# 12613  1711643706
# 12614  1711643510
# 12617  1711642975
# 12620  1711642213
# 12621  1711642181
# 12627  1711640995
# 12639  1711626898
# 14079  1709831393
# 14080  1709831196
# 14496  1709148124
# 14498  1709147670
# 14499  1709147352
# 14500  1709147273
# 14501  1709147077
# 14504  1709146453
# 14505  1709146360
# 14507  1709146152
# 14509  1709145756
# 14510  1709145666
# 14531  1709061755
# 14532  1709061602
# 14584  1709046499
# 14585  1709046330
# 14591  1709044672
# 15520  1708007780
# 15767  1707512260
# 15774  1707510237
# 15777  1707506702
# 15783  1707505323
# 15784  1707505274
# 15829  1707490868
# 15831  1707490518
# 15836  1707489138
# 16816  1706036373
# 16819  1706030585
# 16822  1706029889
# 16824  1706029050
# 17278  1705692053
# 17279  1705691894
# 17283  1705690881
# 17284  1705690759
# 17290  1705688930
# 17291  1705688829
# 17301  1705683477
# 17396  1705519128
# 17399  1705518225
# 17673  1704907399
# 17854  1704491865
# 17855  1704491508
# 17856  1704491390
# 17857  1704491298
# 17858  1704491139
# 17859  1704491037
# 17860  1704490930
# 17861  1704490567
# 17862  1704490492
# 17864  1704490221
# 17865  1704490117
# 17866  1704489312
# 17867  1704489250
# 17868  1704488634

# %% [markdown]
# These are radio scrobbles from a radio app, mostly. I'm comfortable removing them.

# %%
# Drop rows with null values in any column
scrobbles.dropna(inplace=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Counting the Scrobbles

# %%
# Extract the primary artist (first one listed) before grouping
scrobbles['artist'] = scrobbles['artist'].str.split(',').str[0].str.strip()

# Group by the cleaned artist and album to count the number of times each album was played
album_counts = scrobbles.groupby(['artist', 'album', 'album_art']).size().reset_index(name='scrobb_num')

# %%
# Export the result to CSV
output_path = 'Data/scrobbles_summary.csv'
album_counts.to_csv(output_path, index=False)

# %%
album_counts.to_csv('Data/scrobbles_summary.csv', index=False)

# %%
album_counts.columns
# Out:
# Index(['artist', 'album', 'album_art', 'scrobb_num'], dtype='object')

# %% [markdown]
# > Previewing the data, albums that have a featured artist for a song or more were counted as different albums. I noticed a few where the artist name was seperated by a comma with the featured artist.
# >
# > i took care of it in the above cell blocks, but want to leave this here to maybe incorporate into the blog narrative.

# %% [markdown]
# # IMPORTING LIKED.CSV
# These are all of the songs I've ever liked on spotify, downloaded as a csv from exportify.net

# %%
liked = pd.read_csv('Data/liked.csv', on_bad_lines='skip')

# %%
liked
# Out:
#                     Track ID                    Track Name  \
# 0     4asjU3sDnn3002bTJIg2vZ               Missed the Boat
# 1     0Fe3WxeO6lZZxj7ytvbDUh                     Dashboard
# 2     45tBkNCWL867mdQDjSmQ6q               Too Many Things
# 3     7uHpXA3rYfs1EqFHogCwDj                All In My Head
# 4     6vyKPAESyy0nmIiOCWwyLO                  Jerry's Song
# ...                      ...                           ...
# 5502  1dnTzkUEdwm9jrmdpKSfWU  Mercy Mercy Me (The Ecology)
# 5503  4WPaMPLhdPJyZvFSHTzHOk                        Angels
# 5504  0kkKlkEIHdcQbTQlEkAdgp                        Snails
# 5505  0Mfwz6JTTMrwXo2XIj7WGU                        Salina
# 5506  2bRcdM43uOF5k6RK1g2QfD                 Paint It Blue
#
#                                   Album Name      Artist Name(s) Release Date  \
# 0     We Were Dead Before The Ship Even Sank        Modest Mouse   2007-03-20
# 1     We Were Dead Before The Ship Even Sank        Modest Mouse   2007-03-20
# 2                              No Obligation    The Linda Lindas   2024-10-11
# 3                              No Obligation    The Linda Lindas   2024-10-11
# 4                             Seed of a Seed   Haley Heynderickx   2024-11-01
# ...                                      ...                 ...          ...
# 5502                         What's Going On         Marvin Gaye   1971-05-21
# 5503                                    2045       Parris Chariz   2020-07-17
# 5504      Dog Problems (Bonus Track Version)          The Format   2006-07-11
# 5505      Emotionalism (Bonus Track Version)  The Avett Brothers   2007-05-15
# 5506                                   Waves         Alex Schaaf   2018-08-07
#
#       Duration (ms)  Popularity  Added By              Added At  \
# 0            264813          54       NaN  2024-11-13T17:20:04Z
# 1            246173          58       NaN  2024-11-13T16:06:37Z
# 2            155893          36       NaN  2024-11-11T23:15:57Z
# 3            201187          47       NaN  2024-11-11T23:08:47Z
# 4            195360          45       NaN  2024-11-09T18:09:28Z
# ...             ...         ...       ...                   ...
# 5502         196466           0       NaN  2020-12-20T19:19:33Z
# 5503         186184          11       NaN  2020-12-20T19:19:33Z
# 5504         249133           0       NaN  2020-12-20T19:19:33Z
# 5505         284040          30       NaN  2020-12-20T19:19:32Z
# 5506         305156           0       NaN  2020-12-20T19:19:32Z
#
#                                                  Genres  \
# 0     alternative rock,chamber pop,indie rock,indiet...
# 1     alternative rock,chamber pop,indie rock,indiet...
# 2                                            riot grrrl
# 3                                            riot grrrl
# 4       countrygaze,indie pop,portland indie,small room
# ...                                                 ...
# 5502  classic soul,motown,neo soul,northern soul,qui...
# 5503                   christian hip hop,christian trap
# 5504                                                emo
# 5505  indie folk,new americana,north carolina indie,...
# 5506                                  minneapolis indie
#
#                  Record Label  \t\t\t\tDanceability  Energy  Key  Loudness  \
# 0                        Epic                 0.710   0.698    2    -5.797
# 1                        Epic                 0.639   0.903   11    -5.013
# 2                     Epitaph                 0.572   0.900    7    -2.570
# 3                     Epitaph                 0.536   0.861    0    -4.443
# 4     Mama Bird Recording Co.                 0.405   0.234    8   -15.601
# ...                       ...                   ...     ...  ...       ...
# 5502                   Motown                 0.499   0.633    6   -12.145
# 5503   RMG Amplify / World 45                 0.609   0.700    0    -7.018
# 5504         The Vanity Label                 0.682   0.548    4    -8.825
# 5505          Ramseur Records                 0.452   0.235    1   -10.178
# 5506          Offline Records                 0.608   0.327    7   -14.413
#
#       Mode  Speechiness  Acousticness  Instrumentalness  Liveness  Valence  \
# 0        1       0.0332      0.069700          0.000000    0.4780   0.8520
# 1        0       0.0371      0.009630          0.000071    0.1740   0.9600
# 2        1       0.0436      0.000215          0.267000    0.4280   0.8620
# 3        1       0.0511      0.011100          0.000004    0.1140   0.7130
# 4        0       0.0338      0.847000          0.089700    0.1090   0.1990
# ...    ...          ...           ...               ...       ...      ...
# 5502     0       0.0445      0.373000          0.716000    0.0876   0.4740
# 5503     1       0.0407      0.002670          0.000000    0.3650   0.1560
# 5504     1       0.0240      0.095200          0.060200    0.2730   0.6190
# 5505     1       0.0435      0.847000          0.000438    0.1350   0.0654
# 5506     1       0.0303      0.936000          0.000348    0.3820   0.1540
#
#         Tempo  Time Signature
# 0     104.007               4
# 1     135.938               4
# 2     156.938               4
# 3     145.017               4
# 4     119.977               4
# ...       ...             ...
# 5502   93.238               4
# 5503  169.987               4
# 5504   93.998               4
# 5505  118.097               4
# 5506  128.018               4
#
# [5507 rows x 23 columns]

# %%
liked.columns = liked.columns.str.strip().str.replace('\t', '', regex=True)

# %% [markdown]
# Removing likes from before 2024:

# %%
# Use .loc explicitly to avoid the warning
liked = liked.loc[liked['Added At'] >= '2024-01-01'].copy()

# Convert 'Added At' to datetime format
liked['Added At'] = pd.to_datetime(liked['Added At'])

# Confirm the filter worked
liked.head()
# Out:
#                  Track ID       Track Name  \
# 0  4asjU3sDnn3002bTJIg2vZ  Missed the Boat
# 1  0Fe3WxeO6lZZxj7ytvbDUh        Dashboard
# 2  45tBkNCWL867mdQDjSmQ6q  Too Many Things
# 3  7uHpXA3rYfs1EqFHogCwDj   All In My Head
# 4  6vyKPAESyy0nmIiOCWwyLO     Jerry's Song
#
#                                Album Name     Artist Name(s) Release Date  \
# 0  We Were Dead Before The Ship Even Sank       Modest Mouse   2007-03-20
# 1  We Were Dead Before The Ship Even Sank       Modest Mouse   2007-03-20
# 2                           No Obligation   The Linda Lindas   2024-10-11
# 3                           No Obligation   The Linda Lindas   2024-10-11
# 4                          Seed of a Seed  Haley Heynderickx   2024-11-01
#
#    Duration (ms)  Popularity  Added By                  Added At  \
# 0         264813          54       NaN 2024-11-13 17:20:04+00:00
# 1         246173          58       NaN 2024-11-13 16:06:37+00:00
# 2         155893          36       NaN 2024-11-11 23:15:57+00:00
# 3         201187          47       NaN 2024-11-11 23:08:47+00:00
# 4         195360          45       NaN 2024-11-09 18:09:28+00:00
#
#                                               Genres             Record Label  \
# 0  alternative rock,chamber pop,indie rock,indiet...                     Epic
# 1  alternative rock,chamber pop,indie rock,indiet...                     Epic
# 2                                         riot grrrl                  Epitaph
# 3                                         riot grrrl                  Epitaph
# 4    countrygaze,indie pop,portland indie,small room  Mama Bird Recording Co.
#
#    Danceability  Energy  Key  Loudness  Mode  Speechiness  Acousticness  \
# 0         0.710   0.698    2    -5.797     1       0.0332      0.069700
# 1         0.639   0.903   11    -5.013     0       0.0371      0.009630
# 2         0.572   0.900    7    -2.570     1       0.0436      0.000215
# 3         0.536   0.861    0    -4.443     1       0.0511      0.011100
# 4         0.405   0.234    8   -15.601     0       0.0338      0.847000
#
#    Instrumentalness  Liveness  Valence    Tempo  Time Signature
# 0          0.000000     0.478    0.852  104.007               4
# 1          0.000071     0.174    0.960  135.938               4
# 2          0.267000     0.428    0.862  156.938               4
# 3          0.000004     0.114    0.713  145.017               4
# 4          0.089700     0.109    0.199  119.977               4

# %%
liked.shape
# Out:
# (314, 23)

# %%
liked.columns
# Out:
# Index(['Track ID', 'Track Name', 'Album Name', 'Artist Name(s)',
#        'Release Date', 'Duration (ms)', 'Popularity', 'Added By', 'Added At',
#        'Genres', 'Record Label', 'Danceability', 'Energy', 'Key', 'Loudness',
#        'Mode', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo', 'Time Signature'],
#       dtype='object')

# %% [markdown]
# ## IMPORTING 2024.csv

# %%
best = pd.read_csv('Data/2024.csv', on_bad_lines='skip')

# %%
best.head()
# Out:
#                  Track ID           Track Name      Album Name Artist Name(s)  \
# 0  0UOeq7bSskoJa4cJaJOmFS              Ticking  Letter to Self        SPRINTS
# 1  02bA26OEe0nNFyE3YcNx4K                Heavy  Letter to Self        SPRINTS
# 2  7IPDhCIQlpvxVxtC1Q7Jq4            Cathedral  Letter to Self        SPRINTS
# 3  65fPteG9ctHt2rrJxlbMr8  Shaking Their Hands  Letter to Self        SPRINTS
# 4  4UgkFdXpJD0fhw06BMk0bz    Adore Adore Adore  Letter to Self        SPRINTS
#
#   Release Date  Duration (ms)  Popularity                   Added By  \
# 0   2024-01-05         186949          32  mmr4r23xnc6oh1c77lysfbqg4
# 1   2024-01-05         207409          45  mmr4r23xnc6oh1c77lysfbqg4
# 2   2024-01-05         179694          31  mmr4r23xnc6oh1c77lysfbqg4
# 3   2024-01-05         222489          30  mmr4r23xnc6oh1c77lysfbqg4
# 4   2024-01-05         157766          37  mmr4r23xnc6oh1c77lysfbqg4
#
#                Added At                                       Genres  \
# 0  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 1  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 2  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 3  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 4  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
#
#   Record Label  \t\t\t\tDanceability  Energy   Key  Loudness  Mode  \
# 0   City Slang                 0.376   0.620  11.0    -6.490   1.0
# 1   City Slang                 0.348   0.705  11.0    -5.925   1.0
# 2   City Slang                 0.535   0.699   7.0    -6.231   1.0
# 3   City Slang                 0.214   0.851   4.0    -5.658   0.0
# 4   City Slang                 0.412   0.877   4.0    -4.401   0.0
#
#    Speechiness  Acousticness  Instrumentalness  Liveness  Valence    Tempo  \
# 0       0.3440       0.02500          0.076500    0.0934    0.291  175.574
# 1       0.0591       0.00435          0.000738    0.0877    0.189   88.581
# 2       0.0473       0.00978          0.002700    0.0887    0.397  119.056
# 3       0.0533       0.19900          0.108000    0.1330    0.551   89.485
# 4       0.2570       0.01070          0.000107    0.1010    0.402  176.054
#
#    Time Signature
# 0             4.0
# 1             4.0
# 2             4.0
# 3             4.0
# 4             4.0

# %%
best.columns = best.columns.str.strip().str.replace('\t', '')
best.columns
# Out:
# Index(['Track ID', 'Track Name', 'Album Name', 'Artist Name(s)',
#        'Release Date', 'Duration (ms)', 'Popularity', 'Added By', 'Added At',
#        'Genres', 'Record Label', 'Danceability', 'Energy', 'Key', 'Loudness',
#        'Mode', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo', 'Time Signature'],
#       dtype='object')

# %% [markdown]
# ## Cleaning Artist Names and Album Names

# %%
# Ensure that artist names have no leading/trailing spaces and commas are handled properly
liked['Artist Name(s)'] = liked['Artist Name(s)'].str.replace(r',\s*', ',', regex=True).str.strip()
best['Artist Name(s)'] = best['Artist Name(s)'].str.replace(r',\s*', ',', regex=True).str.strip()

# Clean the album names too (if needed, removing any leading/trailing spaces)
liked['Album Name'] = liked['Album Name'].str.strip()
best['Album Name'] = best['Album Name'].str.strip()

# %%
# Keep only the first artist before the comma
liked['Artist Name(s)'] = liked['Artist Name(s)'].str.split(',').str[0].str.strip()
best['Artist Name(s)'] = best['Artist Name(s)'].str.split(',').str[0].str.strip()

# %%
liked.head(5)
# Out:
#                  Track ID       Track Name  \
# 0  4asjU3sDnn3002bTJIg2vZ  Missed the Boat
# 1  0Fe3WxeO6lZZxj7ytvbDUh        Dashboard
# 2  45tBkNCWL867mdQDjSmQ6q  Too Many Things
# 3  7uHpXA3rYfs1EqFHogCwDj   All In My Head
# 4  6vyKPAESyy0nmIiOCWwyLO     Jerry's Song
#
#                                Album Name     Artist Name(s) Release Date  \
# 0  We Were Dead Before The Ship Even Sank       Modest Mouse   2007-03-20
# 1  We Were Dead Before The Ship Even Sank       Modest Mouse   2007-03-20
# 2                           No Obligation   The Linda Lindas   2024-10-11
# 3                           No Obligation   The Linda Lindas   2024-10-11
# 4                          Seed of a Seed  Haley Heynderickx   2024-11-01
#
#    Duration (ms)  Popularity  Added By                  Added At  \
# 0         264813          54       NaN 2024-11-13 17:20:04+00:00
# 1         246173          58       NaN 2024-11-13 16:06:37+00:00
# 2         155893          36       NaN 2024-11-11 23:15:57+00:00
# 3         201187          47       NaN 2024-11-11 23:08:47+00:00
# 4         195360          45       NaN 2024-11-09 18:09:28+00:00
#
#                                               Genres             Record Label  \
# 0  alternative rock,chamber pop,indie rock,indiet...                     Epic
# 1  alternative rock,chamber pop,indie rock,indiet...                     Epic
# 2                                         riot grrrl                  Epitaph
# 3                                         riot grrrl                  Epitaph
# 4    countrygaze,indie pop,portland indie,small room  Mama Bird Recording Co.
#
#    Danceability  Energy  Key  Loudness  Mode  Speechiness  Acousticness  \
# 0         0.710   0.698    2    -5.797     1       0.0332      0.069700
# 1         0.639   0.903   11    -5.013     0       0.0371      0.009630
# 2         0.572   0.900    7    -2.570     1       0.0436      0.000215
# 3         0.536   0.861    0    -4.443     1       0.0511      0.011100
# 4         0.405   0.234    8   -15.601     0       0.0338      0.847000
#
#    Instrumentalness  Liveness  Valence    Tempo  Time Signature
# 0          0.000000     0.478    0.852  104.007               4
# 1          0.000071     0.174    0.960  135.938               4
# 2          0.267000     0.428    0.862  156.938               4
# 3          0.000004     0.114    0.713  145.017               4
# 4          0.089700     0.109    0.199  119.977               4

# %%
best.head(5)
# Out:
#                  Track ID           Track Name      Album Name Artist Name(s)  \
# 0  0UOeq7bSskoJa4cJaJOmFS              Ticking  Letter to Self        SPRINTS
# 1  02bA26OEe0nNFyE3YcNx4K                Heavy  Letter to Self        SPRINTS
# 2  7IPDhCIQlpvxVxtC1Q7Jq4            Cathedral  Letter to Self        SPRINTS
# 3  65fPteG9ctHt2rrJxlbMr8  Shaking Their Hands  Letter to Self        SPRINTS
# 4  4UgkFdXpJD0fhw06BMk0bz    Adore Adore Adore  Letter to Self        SPRINTS
#
#   Release Date  Duration (ms)  Popularity                   Added By  \
# 0   2024-01-05         186949          32  mmr4r23xnc6oh1c77lysfbqg4
# 1   2024-01-05         207409          45  mmr4r23xnc6oh1c77lysfbqg4
# 2   2024-01-05         179694          31  mmr4r23xnc6oh1c77lysfbqg4
# 3   2024-01-05         222489          30  mmr4r23xnc6oh1c77lysfbqg4
# 4   2024-01-05         157766          37  mmr4r23xnc6oh1c77lysfbqg4
#
#                Added At                                       Genres  \
# 0  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 1  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 2  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 3  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 4  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
#
#   Record Label  Danceability  Energy   Key  Loudness  Mode  Speechiness  \
# 0   City Slang         0.376   0.620  11.0    -6.490   1.0       0.3440
# 1   City Slang         0.348   0.705  11.0    -5.925   1.0       0.0591
# 2   City Slang         0.535   0.699   7.0    -6.231   1.0       0.0473
# 3   City Slang         0.214   0.851   4.0    -5.658   0.0       0.0533
# 4   City Slang         0.412   0.877   4.0    -4.401   0.0       0.2570
#
#    Acousticness  Instrumentalness  Liveness  Valence    Tempo  Time Signature
# 0       0.02500          0.076500    0.0934    0.291  175.574             4.0
# 1       0.00435          0.000738    0.0877    0.189   88.581             4.0
# 2       0.00978          0.002700    0.0887    0.397  119.056             4.0
# 3       0.19900          0.108000    0.1330    0.551   89.485             4.0
# 4       0.01070          0.000107    0.1010    0.402  176.054             4.0

# %% [markdown]
# ## Counting the number of Tracks Per Album

# %%
# Count the number of tracks for each album
album_track_counts = best.groupby('Album Name').size().reset_index(name='track_count')

# Merge the track counts into the best DataFrame by matching on the 'Album Name'
best = best.merge(album_track_counts, on='Album Name', how='left')

# Now, 'best' will have a 'track_count' column with the number of tracks for each album
best.head()
# Out:
#                  Track ID           Track Name      Album Name Artist Name(s)  \
# 0  0UOeq7bSskoJa4cJaJOmFS              Ticking  Letter to Self        SPRINTS
# 1  02bA26OEe0nNFyE3YcNx4K                Heavy  Letter to Self        SPRINTS
# 2  7IPDhCIQlpvxVxtC1Q7Jq4            Cathedral  Letter to Self        SPRINTS
# 3  65fPteG9ctHt2rrJxlbMr8  Shaking Their Hands  Letter to Self        SPRINTS
# 4  4UgkFdXpJD0fhw06BMk0bz    Adore Adore Adore  Letter to Self        SPRINTS
#
#   Release Date  Duration (ms)  Popularity                   Added By  \
# 0   2024-01-05         186949          32  mmr4r23xnc6oh1c77lysfbqg4
# 1   2024-01-05         207409          45  mmr4r23xnc6oh1c77lysfbqg4
# 2   2024-01-05         179694          31  mmr4r23xnc6oh1c77lysfbqg4
# 3   2024-01-05         222489          30  mmr4r23xnc6oh1c77lysfbqg4
# 4   2024-01-05         157766          37  mmr4r23xnc6oh1c77lysfbqg4
#
#                Added At                                       Genres  \
# 0  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 1  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 2  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 3  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
# 4  2024-01-05T12:56:38Z  crank wave,irish indie rock,irish post-punk
#
#   Record Label  Danceability  Energy   Key  Loudness  Mode  Speechiness  \
# 0   City Slang         0.376   0.620  11.0    -6.490   1.0       0.3440
# 1   City Slang         0.348   0.705  11.0    -5.925   1.0       0.0591
# 2   City Slang         0.535   0.699   7.0    -6.231   1.0       0.0473
# 3   City Slang         0.214   0.851   4.0    -5.658   0.0       0.0533
# 4   City Slang         0.412   0.877   4.0    -4.401   0.0       0.2570
#
#    Acousticness  Instrumentalness  Liveness  Valence    Tempo  Time Signature  \
# 0       0.02500          0.076500    0.0934    0.291  175.574             4.0
# 1       0.00435          0.000738    0.0877    0.189   88.581             4.0
# 2       0.00978          0.002700    0.0887    0.397  119.056             4.0
# 3       0.19900          0.108000    0.1330    0.551   89.485             4.0
# 4       0.01070          0.000107    0.1010    0.402  176.054             4.0
#
#    track_count
# 0           11
# 1           11
# 2           11
# 3           11
# 4           11

# %%
# Export the cleaned 'best' DataFrame to a CSV file
best.to_csv('Data/2024_cleaned.csv', index=False)

# %% [markdown]
# ## Finding the Liked Songs from 2024's Best Albums

# %%
# Merge liked with best DataFrame on 'Album Name' and 'Artist Name(s)', including 'track_count'
liked_from_best = liked.merge(
    best[['Album Name', 'Artist Name(s)', 'Track Name', 'Popularity', 'track_count']], 
    on=['Album Name', 'Artist Name(s)'], 
    how='inner'
)

# Rename columns to remove suffixes and keep the ones you want
liked_from_best = liked_from_best.rename(columns={
    'Track Name_x': 'Track Name',
    'Popularity_x': 'Popularity'
})

# Drop unnecessary columns (the ones with '_y' suffix)
liked_from_best = liked_from_best.drop(columns=['Track Name_y', 'Popularity_y'])

# Select only the relevant columns after the merge, including 'track_count'
liked_from_best = liked_from_best[['Track Name', 'Album Name', 'Artist Name(s)', 
                                   'Release Date', 'Popularity', 'Genres', 'Record Label', 'track_count']]

# Group by 'Album Name' and 'Artist Name(s)', and for each group, find the song with the highest popularity
most_popular_liked = liked_from_best.loc[liked_from_best.groupby(['Album Name', 'Artist Name(s)'])['Popularity'].idxmax()]

# Now for albums with no liked songs, we select the most popular song from the 'best' DataFrame, including 'track_count'
most_popular_all = best[['Album Name', 'Artist Name(s)', 'Track Name', 'Popularity', 
                         'Release Date', 'Genres', 'Record Label', 'track_count']].sort_values(
    'Popularity', ascending=False
).drop_duplicates('Album Name')

# Merge both datasets: liked songs and the most popular for albums without liked songs
final_data = pd.concat([most_popular_liked, most_popular_all]).drop_duplicates(
    subset=['Album Name', 'Artist Name(s)'], keep='first'
)

# Sort by album to make it easier to read
final_data = final_data.sort_values(['Album Name', 'Artist Name(s)'])

# Display the final result, including 'track_count'
final_data = final_data[['Album Name', 'Artist Name(s)', 'Track Name', 
                         'Popularity', 'Release Date', 'Genres', 'Record Label', 'track_count']]

# %%
final_data
# Out:
#                                          Album Name    Artist Name(s)  \
# 620                                      $10 Cowboy  Charley Crockett
# 78    4 Hits & A Miss - The Essential Richard Swift     Richard Swift
# 1678                                    A Minute...       Myles Smith
# 1446                       A Modern Day Distraction         Jake Bugg
# 1151                         A Sacred Way of Living      Easy Sleeper
# ...                                             ...               ...
# 1160                                        Willson              Ashe
# 1121                               Wish On The Bone        Why Bonnie
# 633                                      Worldviews           Annabel
# 862                                    another year      Brother Bird
# 541                                        spittake        meg elsier
#
#                Track Name  Popularity Release Date  \
# 620            $10 Cowboy          50   2024-04-26
# 78              Dirty Jim          23   2024-11-01
# 1678     Nice To Meet You          79   2024-11-08
# 1446   Never Said Goodbye          47   2024-10-04
# 1151           Timekeeper          25   2024-08-30
# ...                   ...         ...          ...
# 1160  Running Out Of Time          47   2024-09-06
# 1121     Wish On The Bone          26   2024-08-30
# 633   We Are Where We Are           2   2024-06-14
# 862         state of mind          18   2024-03-08
# 541               takeout           8   2024-06-28
#
#                                   Genres          Record Label  track_count
# 620     new americana,southern americana           Son of Davy           12
# 78                                   NaN     Secretly Canadian           14
# 1678               singer-songwriter pop     RCA Records Label            7
# 1446        modern rock,nottingham indie     RCA Records Label           12
# 1151                                 NaN          Easy Sleeper            9
# ...                                  ...                   ...          ...
# 1160                               alt z                  Ashe           12
# 1121  bedroom pop,bubblegrunge,dreamgaze             Fire Talk           11
# 633                          midwest emo          Tiny Engines           12
# 862                                  NaN  Easy Does It Records           11
# 541                                  NaN           ૮ ˶ᵔ ᵕ ᵔ˶ ა           11
#
# [149 rows x 8 columns]

# %%
print(final_data.columns)
# Out:
# Index(['Album Name', 'Artist Name(s)', 'Track Name', 'Popularity',
#        'Release Date', 'Genres', 'Record Label', 'track_count'],
#       dtype='object')

# %% [markdown]
# Saving this list that essentially has one row for each album, along with other important metrics for my final product.

# %%
final_data.to_csv('Data/best_song.csv', index=False)

# %% [markdown]
# ---

# %%
album_counts

# %%
final_data

# %%
print("final_data columns:", final_data.columns)
print("track_counts columns:", track_counts.columns)
print("album_counts columns:", album_counts.columns)
# Out:
# final_data columns: Index(['Album Name', 'Artist Name(s)', 'Track Name', 'Popularity',
#        'Release Date', 'Genres', 'Record Label', 'track_count',
#        'num_of_tracks'],
#       dtype='object')
# track_counts columns: Index(['Album Name', 'Artist Name(s)', 'num_of_tracks'], dtype='object')
# album_counts columns: Index(['artist', 'album', 'album_art', 'scrobb_num'], dtype='object')

# %%
# Count the number of tracks per album and artist
track_counts = best.groupby(['Album Name', 'Artist Name(s)']).size().reset_index(name='num_of_tracks')

# %%
# Calculate the number of liked songs per album and artist
liked_count = liked.groupby(['Album Name', 'Artist Name(s)']).size().reset_index(name='liked_count')

# Merge liked_count with final_data
final_data = pd.merge(final_data, liked_count, on=['Album Name', 'Artist Name(s)'], how='left')

# Merge track counts with final_data
final_data = pd.merge(final_data, track_counts, on=['Album Name', 'Artist Name(s)'], how='left')

# Merge album_art and scrobb_num with final_data from album_counts
final_data = pd.merge(final_data, album_counts[['Album Name', 'Artist Name(s)', 'album_art', 'scrobb_num']], 
                      on=['Album Name', 'Artist Name(s)'], how='left')

# Check for '_x' and '_y' columns and resolve duplicates for 'num_of_tracks'
if 'num_of_tracks_x' in final_data.columns:
    final_data['num_of_tracks'] = final_data['num_of_tracks_x']
elif 'num_of_tracks_y' in final_data.columns:
    final_data['num_of_tracks'] = final_data['num_of_tracks_y']

# Drop unnecessary columns if they exist
final_data = final_data.drop(columns=['num_of_tracks_x', 'num_of_tracks_y'], errors='ignore')

# Reorder the columns for clarity
final_data = final_data[['Album Name', 'Artist Name(s)', 'Track Name', 
                         'Popularity', 'Release Date', 'Genres', 'Record Label', 
                         'track_count', 'liked_count', 'num_of_tracks', 
                         'album_art', 'scrobb_num']]

# Display a sample of the data to confirm it worked
final_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[118], line 24
#      21 final_data = final_data.drop(columns=['num_of_tracks_x', 'num_of_tracks_y'], errors='ignore')
#      23 # Reorder the columns for clarity
# ---> 24 final_data = final_data[['Album Name', 'Artist Name(s)', 'Track Name',
#      25                          'Popularity', 'Release Date', 'Genres', 'Record Label',
#      26                          'track_count', 'liked_count', 'num_of_tracks',
#      27                          'album_art', 'scrobb_num']]
#      29 # Display a sample of the data to confirm it worked
#      30 final_data.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['album_art', 'scrobb_num'] not in index"

# %%
# Check the columns in final_data after merge
print("Columns in final_data after merge:")
print(final_data.columns)

# %%
# Inspect the columns in final_data after the merge to ensure the right column is there
print(final_data.columns)

# If 'num_of_tracks_y' exists, assign it to 'num_of_tracks'
if 'num_of_tracks_y' in final_data.columns:
    final_data['num_of_tracks'] = final_data['num_of_tracks_y']
    # Drop the unnecessary columns 'num_of_tracks_x' and 'num_of_tracks_y'
    final_data = final_data.drop(columns=['num_of_tracks_x', 'num_of_tracks_y'])

# Display the cleaned data
final_data.head()

# %%
album_counts.columns

# %%
# Rename columns in album_counts to match the ones in final_data for consistency
album_counts = album_counts.rename(columns={'album': 'Album Name', 'artist': 'Artist Name(s)'})

# Merge album_art into final_data based on 'Album Name' and 'Artist Name(s)'
final_data = pd.merge(final_data, album_counts[['Album Name', 'Artist Name(s)', 'album_art']], 
                      on=['Album Name', 'Artist Name(s)'], how='left')

# Display the final data with album art
final_data.head()

# %%
final_data.columns

# %%
num_tracks_best

# %%
# Count the number of liked songs for each album
liked_counts = liked.groupby(['Album Name', 'Artist Name(s)'])['Track ID'].count().reset_index()

# Rename the 'Track ID' column to 'liked_count' to clarify what it represents
liked_counts = liked_counts.rename(columns={'Track ID': 'liked_count'})

# Merge the liked_count into final_data
final_data = pd.merge(final_data, liked_counts, on=['Album Name', 'Artist Name(s)'], how='left')

# Display the updated final_data with the count of liked songs per album
final_data.head()

# %%
scrobbles.columns

# %%
album_counts.columns

# %%
final_data.columns

# %%
# Merge 'scrobb_num' from album_counts into final_data
final_data = pd.merge(final_data, album_counts[['Album Name', 'Artist Name(s)', 'scrobb_num']], 
                      on=['Album Name', 'Artist Name(s)'], how='left')

# Rename 'scrobb_num' to 'faved'
final_data = final_data.rename(columns={'scrobb_num': 'scrobbles'})

# Display the updated final_data with the 'faved' column
final_data.head()

# %%
final_data.to_excel('Data/2024_cleaned_preview.xlsx', index = False)
